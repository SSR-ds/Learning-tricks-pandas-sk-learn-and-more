# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1 = pd.read_csv("Kaggle Airline Survey.csv")
data2 = pd.read_csv('CA - Housing Price Prediction.csv')

# %%
data1.head()
# Out:
#        id satisfaction_v2  Gender   Customer Type   Age   Type of Travel  \
# 0   11112       satisfied  Female  Loyal Customer  65.0  Personal Travel
# 1  110278       satisfied    Male  Loyal Customer  47.0  Personal Travel
# 2  103199       satisfied  Female  Loyal Customer  15.0  Personal Travel
# 3   47462       satisfied  Female  Loyal Customer  60.0  Personal Travel
# 4  120011       satisfied  Female  Loyal Customer  70.0  Personal Travel
#
#       Class  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0       Eco            265.0           0.0                                0.0
# 1  Business           2464.0           0.0                                0.0
# 2       Eco           2138.0           0.0                                0.0
# 3       Eco            623.0           0.0                                0.0
# 4       Eco            354.0           0.0                                0.0
#
# ...

# %%
data1.columns
# Out:
# Index(['id', 'satisfaction_v2', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
data1.shape
# Out:
# (4099, 24)

# %%
data2.columns
# Out:
# Index(['Id', 'GrLivArea', 'Street', 'OverallQual', 'GarageCars', 'GarageArea',
#        'LandSlope', 'TotRmsAbvGrd', 'Utilities', 'FullBath', 'X1stFlrSF',
#        'TotalBsmtSF', 'age', 'YearBuilt', 'YearRemodAdd', 'Fireplaces',
#        'GarageYrBlt', 'MasVnrArea', 'LotArea', 'X2ndFlrSF', 'BedroomAbvGr',
#        'BsmtFinSF1', 'HalfBath', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ## Reverse column order in a dataframe

# %%
data1.loc[:,::-1]
# Out:
#       Arrival Delay in Minutes  Departure Delay in Minutes  Online boarding  \
# 0                          0.0                         0.0              2.0
# 1                        305.0                       310.0              2.0
# 2                          0.0                         0.0              2.0
# 3                          0.0                         0.0              3.0
# 4                          0.0                         0.0              5.0
# ...                        ...                         ...              ...
# 4094                      35.0                        18.0              5.0
# 4095                      78.0                        72.0              3.0
# 4096                      68.0                        40.0              3.0
# 4097                       0.0                         0.0              5.0
# 4098                      25.0                        23.0              3.0
#
# ...

# %% [markdown]
# ## Reverse row order in a dataframe

# %%
data1.loc[::-1]
# Out:
#           id          satisfaction_v2  Gender   Customer Type   Age  \
# 4098   73729  neutral or dissatisfied  Female  Loyal Customer  63.0
# 4097   91516  neutral or dissatisfied  Female  Loyal Customer  66.0
# 4096    9689                satisfied    Male  Loyal Customer  45.0
# 4095      90                satisfied    Male  Loyal Customer  41.0
# 4094   56128                satisfied  Female  Loyal Customer  51.0
# ...      ...                      ...     ...             ...   ...
# 4     120011                satisfied  Female  Loyal Customer  70.0
# 3      47462                satisfied  Female  Loyal Customer  60.0
# 2     103199                satisfied  Female  Loyal Customer  15.0
# 1     110278                satisfied    Male  Loyal Customer  47.0
# 0      11112                satisfied  Female  Loyal Customer  65.0
#
#        Type of Travel     Class  Flight Distance  Seat comfort  \
# 4098  Personal Travel       Eco            192.0           2.0
# ...

# %% [markdown]
# ## Reverse row and column order in a dataframe

# %%
data1.loc[::-1,::-1]
# Out:
#       Arrival Delay in Minutes  Departure Delay in Minutes  Online boarding  \
# 4098                      25.0                        23.0              3.0
# 4097                       0.0                         0.0              5.0
# 4096                      68.0                        40.0              3.0
# 4095                      78.0                        72.0              3.0
# 4094                      35.0                        18.0              5.0
# ...                        ...                         ...              ...
# 4                          0.0                         0.0              5.0
# 3                          0.0                         0.0              3.0
# 2                          0.0                         0.0              2.0
# 1                        305.0                       310.0              2.0
# 0                          0.0                         0.0              2.0
#
# ...

# %% [markdown]
# ## % of missing values in each column

# %%
data1.isna().mean()
# Out:
# id                                   0.000000
# satisfaction_v2                      0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.010978
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.001220
# Seat comfort                         0.000976
# Departure/Arrival time convenient    0.000488
# Food and drink                       0.005123
# Gate location                        0.000000
# Inflight wifi service                0.005855
# Inflight entertainment               0.014638
# Online support                       0.003903
# Ease of Online booking               0.006099
# On-board service                     0.001464
# Leg room service                     0.006099
# Baggage handling                     0.003659
# Checkin service                      0.000976
# ...

# %% [markdown]
# ## splitting dataframe into two random datasets

# %%
df_1 = data1.sample(frac=0.75,random_state=42)

# %% [markdown]
# 75% of 4099 is 3074

# %%
df_1
# Out:
#           id          satisfaction_v2  Gender   Customer Type   Age  \
# 2820    8729                satisfied  Female  Loyal Customer  48.0
# 889    55554  neutral or dissatisfied    Male  Loyal Customer  25.0
# 2607   77519                satisfied  Female  Loyal Customer  35.0
# 1293   47211                satisfied  Female  Loyal Customer  63.0
# 1670   73956                satisfied  Female  Loyal Customer  54.0
# ...      ...                      ...     ...             ...   ...
# 1719   66288                satisfied  Female  Loyal Customer   9.0
# 3093   75061                satisfied    Male  Loyal Customer  53.0
# 359    68355                satisfied  Female  Loyal Customer  51.0
# 899    95363  neutral or dissatisfied    Male  Loyal Customer  33.0
# 1935  126285                satisfied  Female  Loyal Customer  65.0
#
#        Type of Travel     Class  Flight Distance  Seat comfort  \
# 2820  Personal Travel       Eco            237.0           5.0
# ...

# %% [markdown]
# 25% of 4099 is 1025

# %%
df_2 = data1.drop(df_1.index)

# %%
df_2
# Out:
#           id          satisfaction_v2  Gender   Customer Type   Age  \
# 1     110278                satisfied    Male  Loyal Customer  47.0
# 4     120011                satisfied  Female  Loyal Customer  70.0
# 9       7243                satisfied    Male  Loyal Customer  22.0
# 11    126744                satisfied  Female  Loyal Customer  34.0
# 16    129341                satisfied  Female  Loyal Customer  13.0
# ...      ...                      ...     ...             ...   ...
# 4085   88757                satisfied  Female  Loyal Customer  46.0
# 4086   97959                satisfied    Male  Loyal Customer  18.0
# 4087   43283                satisfied    Male  Loyal Customer  38.0
# 4088   49011                satisfied  Female  Loyal Customer  42.0
# 4092  122376  neutral or dissatisfied    Male  Loyal Customer  37.0
#
#        Type of Travel     Class  Flight Distance  Seat comfort  \
# 1     Personal Travel  Business           2464.0           0.0
# ...
